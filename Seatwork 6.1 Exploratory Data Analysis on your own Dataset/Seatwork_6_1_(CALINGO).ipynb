# %%
filepath = '/content/newegg.csv'

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(filepath)

# %% [markdown]
# # **Datasets of the Computer Components**

# %%
data
# Out:
#       Unnamed: 0 brand_name  \
# 0              0        AMD
# 1              1        AMD
# 2              2        AMD
# 3              3        AMD
# 4              4        AMD
# ...          ...        ...
# 2700         195        NaN
# 2701         196        NaN
# 2702         197        NaN
# 2703         198        NaN
# 2704         199        NaN
#
#                                        items_Decribtion ratings     prices  \
# 0     CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...     (1)  14,723.99
# 1     Kingston 16GB (2 x 8GB) 240-Pin DDR3 SDRAM DDR...     (9)     378.99
# 2     CORSAIR Vengeance LPX 32GB (4 x 8GB) 288-Pin D...     (4)   2,834.99
# 3     CORSAIR Vengeance LPX 128GB (4 x 32GB) 288-Pin...    (42)     661.99
# 4     AMD Ryzen Threadripper 3990X 64-Core 2.9 GHz S...   (691)   1,588.99
# ...                                                 ...     ...        ...
# 2700  EVGA SuperNOVA 1000 T2 220-T2-1000-X1 80+ TITA...     NaN        NaN
# ...

# %% [markdown]
# **Changing the values in the Category Column due to dataset typograhical error**

# %%
data.loc[data["Category"] == "cpu", "Category"] = "CPU"
data.loc[data["Category"] == "gpu", "Category"] = "GPU"
data.loc[data["Category"] == "motherboard", "Category"] = "Motherboard"
data.loc[data["Category"] == "moniter", "Category"] = "Monitor"
data.loc[data["Category"] == "storege", "Category"] = "Storage"
data.loc[data["Category"] == "ram", "Category"] = "RAM"
data.loc[data["Category"] == "power", "Category"] = "Power"

data
# Out:
#       Unnamed: 0 brand_name  \
# 0              0        AMD
# 1              1        AMD
# 2              2        AMD
# 3              3        AMD
# 4              4        AMD
# ...          ...        ...
# 2700         195        NaN
# 2701         196        NaN
# 2702         197        NaN
# 2703         198        NaN
# 2704         199        NaN
#
#                                        items_Decribtion ratings     prices  \
# 0     CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...     (1)  14,723.99
# 1     Kingston 16GB (2 x 8GB) 240-Pin DDR3 SDRAM DDR...     (9)     378.99
# 2     CORSAIR Vengeance LPX 32GB (4 x 8GB) 288-Pin D...     (4)   2,834.99
# 3     CORSAIR Vengeance LPX 128GB (4 x 32GB) 288-Pin...    (42)     661.99
# 4     AMD Ryzen Threadripper 3990X 64-Core 2.9 GHz S...   (691)   1,588.99
# ...                                                 ...     ...        ...
# 2700  EVGA SuperNOVA 1000 T2 220-T2-1000-X1 80+ TITA...     NaN        NaN
# ...

# %% [markdown]
# **Changing the name of the columns to easily identify**

# %%
data.columns = ['Item_No', 'Brand_Name', 'Item_Name', 'Ratings', 'Price', 'Category']
data
# Out:
#       Item_No Brand_Name                                          Item_Name  \
# 0           0        AMD  CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...
# 1           1        AMD  Kingston 16GB (2 x 8GB) 240-Pin DDR3 SDRAM DDR...
# 2           2        AMD  CORSAIR Vengeance LPX 32GB (4 x 8GB) 288-Pin D...
# 3           3        AMD  CORSAIR Vengeance LPX 128GB (4 x 32GB) 288-Pin...
# 4           4        AMD  AMD Ryzen Threadripper 3990X 64-Core 2.9 GHz S...
# ...       ...        ...                                                ...
# 2700      195        NaN  EVGA SuperNOVA 1000 T2 220-T2-1000-X1 80+ TITA...
# 2701      196        NaN  Thermaltake TR2 TR-600 600W ATX12V v2.3 SLI Re...
# 2702      197        NaN  EVGA SuperNOVA 650 P2 220-P2-0650-X1 80+ PLATI...
# 2703      198        NaN  EVGA SuperNOVA 850 PQ, 80 Plus PLATINUM 850W, ...
# 2704      199        NaN  Thermaltake Toughpower PS-TPD-0850MPCGUS-1 850...
#
#      Ratings      Price Category
# ...

# %% [markdown]
# **Checking the amount of CPU, Motherboard, GPU, Monitor, Storage, Ram, Power Components and getting the total number of components**

# %%
cpu_amt = len(data[data['Category'] == "CPU"])
gpu_amt = len(data[data['Category'] == "GPU"])
mobo_amt = len(data[data['Category'] == "Motherboard"])
mon_amt = len(data[data['Category'] == "Monitor"])
stg_amt = len(data[data['Category'] == "Storage"])
ram_amt = len(data[data['Category'] == "RAM"])
psu_amt = len(data[data['Category'] == "Power"])

print("Number of CPUs:",cpu_amt)
print("Number of GPUs:",gpu_amt)
print("Number of Motherboards:",mobo_amt)
print("Number of Monitors:",mon_amt)
print("Number of Storage:",stg_amt)
print("Number of RAMs:",ram_amt)
print("Number of PSUs:",psu_amt)


total = (cpu_amt + gpu_amt + mobo_amt + mon_amt + stg_amt + ram_amt + psu_amt)
print("==================================")
print("Total Number of Components:",total)
# Out:
# Number of CPUs: 135
# Number of GPUs: 410
# Number of Motherboards: 440
# Number of Monitors: 920
# Number of Storage: 440
# Number of RAMs: 160
# Number of PSUs: 200
# ...
# Total Number of Components: 2705

# %% [markdown]
# **Identifying the column names of the dataset**

# %%
col_num = 1
for x in data.columns:
  print(f"{col_num}.",x)
  col_num+=1
# Out:
# 1. Item_No
# 2. Brand_Name
# 3. Item_Name
# 4. Ratings
# 5. Price
# 6. Category

# %% [markdown]
# # **Creating new dataframe for each category**

# %% [markdown]
# **Dataframe for CPUs**

# %%
cpu_df = pd.DataFrame(data)
cpu_dataframe = cpu_df[cpu_df['Category'] == 'CPU'].copy()
cpu_dataframe
# Out:
#      Item_No Brand_Name                                          Item_Name  \
# 0          0        AMD  CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...
# 1          1        AMD  Kingston 16GB (2 x 8GB) 240-Pin DDR3 SDRAM DDR...
# 2          2        AMD  CORSAIR Vengeance LPX 32GB (4 x 8GB) 288-Pin D...
# 3          3        AMD  CORSAIR Vengeance LPX 128GB (4 x 32GB) 288-Pin...
# 4          4        AMD  AMD Ryzen Threadripper 3990X 64-Core 2.9 GHz S...
# ..       ...        ...                                                ...
# 130      130        NaN  Refurbished: AMD Athlon 64 X2 4200+ Brisbane D...
# 131      131        NaN  Refurbished: Intel Core 2 Duo E7200 Wolfdale-3...
# 132      132        NaN  AMD A8-9600 Bristol Ridge Quad-Core 3.1 GHz So...
# 133      133        NaN  Intel Core i7-7820X Skylake-X 8-Core 3.6 GHz L...
# 134      134        NaN    Intel Xeon W2133 Processor Tray CD8067303533204
#
#     Ratings      Price Category
# 0       (1)  14,723.99      CPU
# ...

# %% [markdown]
# **Dataframe for GPUs**

# %%
gpu_df = pd.DataFrame(data)
gpu_dataframe = gpu_df[gpu_df['Category'] == 'GPU'].copy()
gpu_dataframe
# Out:
#      Item_No     Brand_Name  \
# 135        0  Sapphire Tech
# 136        1            MSI
# 137        2       GIGABYTE
# 138        3  Sapphire Tech
# 139        4           EVGA
# ..       ...            ...
# 540      405            NaN
# 541      406            NaN
# 542      407            NaN
# 543      408            NaN
# 544      409            NaN
#
#                                              Item_Name Ratings     Price  \
# 135  CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...     (1)  1,058.99
# 136  Kingston 16GB (2 x 8GB) 240-Pin DDR3 SDRAM DDR...     (2)  1,542.99
# 137  CORSAIR Vengeance LPX 32GB (4 x 8GB) 288-Pin D...     (5)  1,096.99
# 138  CORSAIR Vengeance LPX 128GB (4 x 32GB) 288-Pin...    (11)    586.99
# 139  SAPPHIRE PULSE Radeon RX 5600 XT DirectX 12 10...     (1)  1,208.99
# ..                                                 ...     ...       ...
# 540  Sapphire - 11295-01-20G - Video Card 11295-01-...     NaN       NaN
# ...

# %% [markdown]
# **Dataframe for Motherboards**

# %%
mobo_df = pd.DataFrame(data)
mobo_dataframe = mobo_df[mobo_df['Category'] == 'Motherboard'].copy()
mobo_dataframe
# Out:
#      Item_No Brand_Name                                          Item_Name  \
# 545        0        MSI  CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...
# 546        1        MSI  Kingston 16GB (2 x 8GB) 240-Pin DDR3 SDRAM DDR...
# 547        2        MSI  CORSAIR Vengeance LPX 32GB (4 x 8GB) 288-Pin D...
# 548        3       ASUS  CORSAIR Vengeance LPX 128GB (4 x 32GB) 288-Pin...
# 549        4        MSI  MSI MEG X570 ACE Gaming Motherboard AMD AM4 SA...
# ..       ...        ...                                                ...
# 980      435        NaN  Refurbished: GIGABYTE Z370XP SLI (rev. 1.0) LG...
# 981      436        NaN  Refurbished: MSI Z170A GAMING M3 LGA 1151 Inte...
# 982      437        NaN  Refurbished: GIGABYTE GA-970A-DS3 AM3+ AMD 970...
# 983      438        NaN  Refurbished: GIGABYTE GA-B75M-D3V LGA 1155 Int...
# 984      439        NaN  Refurbished: MSI P55-CD53 LGA 1156 Intel P55 A...
#
#     Ratings     Price     Category
# ...

# %% [markdown]
# **Dataframe for Monitors**

# %%
mon_df = pd.DataFrame(data)
mon_dataframe = mon_df[mon_df['Category'] == 'Monitor'].copy()
mon_dataframe
# Out:
#       Item_No Brand_Name                                          Item_Name  \
# 985         0        MSI  Acer XZ271U Abmiiphzx 27" Quad HD 2560 x 1440 ...
# 986         1        MSI  MSI Optix AG32C 32" Red LED Non-Glare Super Na...
# 987         2        MSI  MSI Optix MAG272QR 27" WQHD 2560 x 1440 (2K) 1...
# 988         3        MSI  MSI Optix MAG27C 27" Full HD 1920 x 1080 1ms (...
# 989         4       ASUS  MSI Optix AG32C 32" Red LED Non-Glare Super Na...
# ...       ...        ...                                                ...
# 1900      915        NaN  Lenovo ThinkVision T24i-19 23.8" Full HD VGA D...
# 1901      916        NaN  Dell E2720HS 27" 1920x1080 Full HD LED IPS 5ms...
# 1902      917        NaN  Dell E2420H 23.8" 1920x1080 Full HD LED IPS 5m...
# 1903      918        NaN  ASUS ROG STRIX XG32VQR 32" (Actual Size 31.5")...
# 1904      919        NaN  Dell SE2216H Black 22" FHD 1080p Widescreen LE...
#
#      Ratings     Price Category
# ...

# %% [markdown]
# **Dataframe for Storages**

# %%
stg_df = pd.DataFrame(data)
stg_dataframe = stg_df[stg_df['Category'] == 'Storage'].copy()
stg_dataframe
# Out:
#       Item_No Brand_Name                                          Item_Name  \
# 1905        0    Seagate  StarTech.com USB3C2ESAT3 3 ft 1m USB C to eSAT...
# 1906        1    Seagate  CRU 31350-1279-0000 Usb 3.0 Writeblocker; Bloc...
# 1907        2    Seagate  SanDisk 256GB Ultra SDXC UHS-I/Class 10 Memory...
# 1908        3    Seagate  Corsair 110Q CC-9011184-WW Black Steel / Plast...
# 1909        4    Seagate  Seagate Technology ST12000NM001G Hard Drive 12...
# ...       ...        ...                                                ...
# 2340      435        NaN  Western Digital Blue WD10EALX 1TB 7200 RPM 32M...
# 2341      436        NaN  Lenovo 1TB PCI-Express 3.0 x4 NVME TLC Interna...
# 2342      437        NaN  Western Digital WD BLACK SN750 NVMe M.2 2280 2...
# 2343      438        NaN  Lenovo 512GB PCI-Express 3.0 x4 NVME TLC Inter...
# 2344      439        NaN  Refurbished: Dell HT953 300GB 15000 RPM 16MB C...
#
#      Ratings     Price Category
# ...

# %% [markdown]
# **Dataframe for RAMs**

# %%
ram_df = pd.DataFrame(data)
ram_dataframe = ram_df[ram_df['Category'] == 'RAM'].copy()
ram_dataframe
# Out:
#       Item_No                 Brand_Name  \
# 2345        0                    Corsair
# 2346        1  Kingston Technology Corp.
# 2347        2                    Corsair
# 2348        3                    Corsair
# 2349        4                    Corsair
# ...       ...                        ...
# 2500      155                        NaN
# 2501      156                        NaN
# 2502      157                        NaN
# 2503      158                        NaN
# 2504      159                        NaN
#
#                                               Item_Name Ratings     Price  \
# 2345  Thermaltake Level 20 RS Motherboard Sync ARGB ...    (43)    415.99
# 2346  Rosewill SRM-01B-450 Micro ATX Mini Tower Desk...   (103)    432.16
# 2347  Antec Performance Series P82 Flow ATX Mid-Towe...    (86)    653.99
# 2348  Phanteks Eclipse P300A High Airflow Full-Metal...    (10)  2,380.99
# 2349  CORSAIR Vengeance RGB Pro 16GB (2 x 8GB) 288-P...     (1)    733.99
# ...

# %% [markdown]
# **Dataframe for Power Supplies**

# %%
psu_df = pd.DataFrame(data)
psu_dataframe = psu_df[psu_df['Category'] == 'Power'].copy()
psu_dataframe
# Out:
#       Item_No Brand_Name                                          Item_Name  \
# 2505        0       EVGA  EVGA SuperNOVA 850 GA, 80 Plus Gold 850W, Full...
# 2506        1       EVGA  EVGA 850 B5, 80 Plus BRONZE 850W, Fully Modula...
# 2507        2       EVGA  EVGA SuperNOVA 750 G5, 80 Plus Gold 750W, Full...
# 2508        3       EVGA  EVGA SuperNOVA 550 GA, 80 Plus Gold 550W, Full...
# 2509        4       EVGA  EVGA SuperNOVA 850 GA, 80 Plus Gold 850W, Full...
# ...       ...        ...                                                ...
# 2700      195        NaN  EVGA SuperNOVA 1000 T2 220-T2-1000-X1 80+ TITA...
# 2701      196        NaN  Thermaltake TR2 TR-600 600W ATX12V v2.3 SLI Re...
# 2702      197        NaN  EVGA SuperNOVA 650 P2 220-P2-0650-X1 80+ PLATI...
# 2703      198        NaN  EVGA SuperNOVA 850 PQ, 80 Plus PLATINUM 850W, ...
# 2704      199        NaN  Thermaltake Toughpower PS-TPD-0850MPCGUS-1 850...
#
#      Ratings   Price Category
# ...

# %% [markdown]
# # **Deleting the Items with no price and getting its mean price**

# %% [markdown]
# **CPU (Central Processing Unit)**

# %%
cpu_dataframe.loc[:,'Price'] = pd.to_numeric(cpu_dataframe.Price, errors = 'coerce')
cpu_dataframe = cpu_dataframe.dropna()
cpu_dataframe

res = 0
total_row = len(cpu_dataframe)
for x in cpu_dataframe['Price']:
  res +=x

mean_price_cpu = round((res/total_row),2)

print("Average Price of CPU Components:",mean_price_cpu)
# Out:
# Average Price of CPU Components: 538.23

# %% [markdown]
# **GPU (Graphics Processing Unit)**

# %%
gpu_dataframe.loc[:,'Price'] = pd.to_numeric(gpu_dataframe.Price, errors = 'coerce')
gpu_dataframe = gpu_dataframe.dropna()
gpu_dataframe

res2 = 0
total_row2 = len(gpu_dataframe)
for x in gpu_dataframe['Price']:
  res2 +=x

mean_price_gpu = round((res2/total_row2),2)
print("Average Price of GPU Components:",mean_price_gpu)
# Out:
# Average Price of GPU Components: 622.16

# %% [markdown]
# **Motherboard**

# %%
mobo_dataframe.loc[:,'Price'] = pd.to_numeric(mobo_dataframe.Price, errors = 'coerce')
mobo_dataframe = mobo_dataframe.dropna()
mobo_dataframe

res3 = 0
total_row3 = len(mobo_dataframe)
for x in mobo_dataframe['Price']:
  res3 += x

mean_price_mobo = round((res3/total_row3),2)
print("Average Price of Motherboard Components:",mean_price_mobo)
# Out:
# Average Price of Motherboard Components: 538.76

# %% [markdown]
# **Monitor**

# %%
mon_dataframe.loc[:,'Price'] = pd.to_numeric(mon_dataframe.Price, errors = 'coerce')
mon_dataframe = mon_dataframe.dropna()
mon_dataframe

res4 = 0
total_row4 = len(mon_dataframe)
for x in mon_dataframe['Price']:
  res4 += x

mean_price_mon = round((res4/total_row4),2)
print("Average Price of Monitor Components:",mean_price_mon)
# Out:
# Average Price of Monitor Components: 620.92

# %% [markdown]
# **Storage**

# %%
stg_dataframe.loc[:,'Price'] = pd.to_numeric(stg_dataframe.Price, errors = 'coerce')
stg_dataframe = stg_dataframe.dropna()
stg_dataframe

res5 = 0
total_row5 = len(stg_dataframe)
for x in stg_dataframe['Price']:
  res5 += x

mean_price_stg = round((res5/total_row5),2)
print("Average Price of Storage Components:",mean_price_stg)
# Out:
# Average Price of Storage Components: 558.98

# %% [markdown]
# **RAM (Random Access Memory)**

# %%
ram_dataframe.loc[:,'Price'] = pd.to_numeric(ram_dataframe.Price, errors = 'coerce')
ram_dataframe = ram_dataframe.dropna()
ram_dataframe

res6 = 0
total_row6 = len(ram_dataframe)
for x in ram_dataframe['Price']:
  res6 += x

mean_price_ram = round((res6/total_row6),2)
print("Average Price of RAM Components:",mean_price_ram)
# Out:
# Average Price of RAM Components: 477.32

# %% [markdown]
# **PSU (Power Supply Unit)**

# %%
psu_dataframe.loc[:,'Price'] = pd.to_numeric(psu_dataframe.Price, errors = 'coerce')
psu_dataframe = psu_dataframe.dropna()
psu_dataframe

res7 = 0
total_row7 = len(psu_dataframe)
for x in psu_dataframe['Price']:
  res7 += x

mean_price_psu = round((res7/total_row7),2)
print("Average Price of Power Supply Components:",mean_price_psu)
# Out:
# Average Price of Power Supply Components: 464.98

# %% [markdown]
# # **Getting the Maximum Price and the Minimum Price for each Components and its Item Name**

# %% [markdown]
# **CPU (Central Processing Unit)**

# %%
max_price_cpu = max(cpu_dataframe['Price'])
min_price_cpu = min(cpu_dataframe['Price'])
print("CPU Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_cpu)
print("Min Price:",min_price_cpu)
# Out:
# CPU Highest and Lowest Price
# ...
# Max Price: 975.65
# Min Price: 181.99

# %% [markdown]
# **GPU (Graphics Processing Unit)**

# %%
max_price_gpu = max(gpu_dataframe['Price'])
min_price_gpu = min(gpu_dataframe['Price'])
print("GPU Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_gpu)
print("Min Price:",min_price_gpu)
# Out:
# GPU Highest and Lowest Price
# ...
# Max Price: 994.64
# Min Price: 147.99

# %% [markdown]
# **Motherboard**

# %%
max_price_mobo = max(mobo_dataframe['Price'])
min_price_mobo = min(mobo_dataframe['Price'])
print("Motherboard Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_mobo)
print("Min Price:",min_price_mobo)
# Out:
# Motherboard Highest and Lowest Price
# ...
# Max Price: 998.73
# Min Price: 173.99

# %% [markdown]
# **Monitor**

# %%
max_price_mon = max(mon_dataframe['Price'])
min_price_mon = min(mon_dataframe['Price'])
print("Monitor Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_mon)
print("Min Price:",min_price_mon)
# Out:
# Monitor Highest and Lowest Price
# ...
# Max Price: 982.19
# Min Price: 266.16

# %% [markdown]
# **Storage**

# %%
max_price_stg = max(stg_dataframe['Price'])
min_price_stg = min(stg_dataframe['Price'])
print("Storage Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_stg)
print("Min Price:",min_price_stg)
# Out:
# Storage Highest and Lowest Price
# ...
# Max Price: 995.99
# Min Price: 121.82

# %% [markdown]
# **RAM (Random Access Memory)**

# %%
max_price_ram = max(ram_dataframe['Price'])
min_price_ram = min(ram_dataframe['Price'])
print("GPU Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_ram)
print("Min Price:",min_price_ram)
# Out:
# GPU Highest and Lowest Price
# ...
# Max Price: 944.99
# Min Price: 132.99

# %% [markdown]
# **PSU (Power Supply Unit)**

# %%
max_price_psu = max(psu_dataframe['Price'])
min_price_psu = min(psu_dataframe['Price'])
print("GPU Highest and Lowest Price")
print("=====================")
print("Max Price:",max_price_psu)
print("Min Price:",min_price_psu)
# Out:
# GPU Highest and Lowest Price
# ...
# Max Price: 999.65
# Min Price: 132.99
